# %% [markdown]
# Here's the schema for the Northwind database:
#
# <img src='images/Northwind_ERD_updated.png'>

# %%
import sqlite3
import pandas as pd

# %%
#Connect to server and create cursor
conn = sqlite3.connect('northwind_small.sqlite')
c = conn.cursor()

# %%
#Create a list of table names and check
table_names = [name[0] for name 
               in c.execute("""SELECT name FROM sqlite_master 
                            WHERE type='table';""").fetchall()]
table_names
# Out:
# ['Employee',
#  'Category',
#  'Customer',
#  'Shipper',
#  'Supplier',
#  'Order',
#  'Product',
#  'OrderDetail',
#  'CustomerCustomerDemo',
#  'CustomerDemographic',
#  'Region',
#  'Territory',
#  'EmployeeTerritory']

# %%
#Create dataframes for each table and check
dfs = []
for table in table_names:
    df = pd.read_sql_query('SELECT * from "'+table+'"', conn)
    new_df_name = table.lower()+"_df" #creates string for new df name
    exec(new_df_name + " = df") #creates df with new name
    #exec() dynamically executes a line of code
    dfs.append(new_df_name)
dfs
# Out:
# ['employee_df',
#  'category_df',
#  'customer_df',
#  'shipper_df',
#  'supplier_df',
#  'order_df',
#  'product_df',
#  'orderdetail_df',
#  'customercustomerdemo_df',
#  'customerdemographic_df',
#  'region_df',
#  'territory_df',
#  'employeeterritory_df']

# %%
employee_df.head()
# Out:
#    Id   LastName FirstName                  Title TitleOfCourtesy   BirthDate  \
# 0   1    Davolio     Nancy   Sales Representative             Ms.  1980-12-08
# 1   2     Fuller    Andrew  Vice President, Sales             Dr.  1984-02-19
# 2   3  Leverling     Janet   Sales Representative             Ms.  1995-08-30
# 3   4    Peacock  Margaret   Sales Representative            Mrs.  1969-09-19
# 4   5   Buchanan    Steven          Sales Manager             Mr.  1987-03-04
#
#      HireDate                     Address      City         Region PostalCode  \
# 0  2024-05-01  507 - 20th Ave. E. Apt. 2A   Seattle  North America      98122
# 1  2024-08-14          908 W. Capital Way    Tacoma  North America      98401
# 2  2024-04-01          722 Moss Bay Blvd.  Kirkland  North America      98033
# 3  2025-05-03        4110 Old Redmond Rd.   Redmond  North America      98052
# 4  2025-10-17             14 Garrett Hill    London  British Isles    SW1 8JR
#
# ...

# %%
employee_df.loc[employee_df.Title == 'Sales Representative']
# Out:
#    Id   LastName FirstName                 Title TitleOfCourtesy   BirthDate  \
# 0   1    Davolio     Nancy  Sales Representative             Ms.  1980-12-08
# 2   3  Leverling     Janet  Sales Representative             Ms.  1995-08-30
# 3   4    Peacock  Margaret  Sales Representative            Mrs.  1969-09-19
# 5   6     Suyama   Michael  Sales Representative             Mr.  1995-07-02
# 6   7       King    Robert  Sales Representative             Mr.  1992-05-29
# 8   9  Dodsworth      Anne  Sales Representative             Ms.  1998-01-27
#
#      HireDate                        Address      City         Region  \
# 0  2024-05-01     507 - 20th Ave. E. Apt. 2A   Seattle  North America
# 2  2024-04-01             722 Moss Bay Blvd.  Kirkland  North America
# 3  2025-05-03           4110 Old Redmond Rd.   Redmond  North America
# 5  2025-10-17       Coventry House Miner Rd.    London  British Isles
# 6  2026-01-02  Edgeham Hollow Winchester Way    London  British Isles
# ...

# %%
category_df.head()
# Out:
#    Id    CategoryName                                        Description
# 0   1       Beverages        Soft drinks, coffees, teas, beers, and ales
# 1   2      Condiments  Sweet and savory sauces, relishes, spreads, an...
# 2   3     Confections                Desserts, candies, and sweet breads
# 3   4  Dairy Products                                            Cheeses
# 4   5  Grains/Cereals                Breads, crackers, pasta, and cereal

# %%
customer_df.head()
# Out:
#       Id                         CompanyName         ContactName  \
# 0  ALFKI                 Alfreds Futterkiste        Maria Anders
# 1  ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2  ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3  AROUT                     Around the Horn        Thomas Hardy
# 4  BERGS                  Berglunds snabbköp  Christina Berglund
#
#            ContactTitle                        Address         City  \
# 0  Sales Representative                  Obere Str. 57       Berlin
# 1                 Owner  Avda. de la Constitución 2222  México D.F.
# 2                 Owner                Mataderos  2312  México D.F.
# 3  Sales Representative                120 Hanover Sq.       London
# 4   Order Administrator                Berguvsvägen  8        Luleå
#
#             Region PostalCode  Country           Phone             Fax
# 0   Western Europe      12209  Germany     030-0074321     030-0076545
# ...

# %%
customer_df.Region.value_counts()
# Out:
# Western Europe     28
# South America      16
# North America      16
# Southern Europe    10
# British Isles       8
# Central America     5
# Northern Europe     4
# Scandinavia         3
# Eastern Europe      1
# Name: Region, dtype: int64

# %%
shipper_df.head()
# Out:
#    Id       CompanyName           Phone
# 0   1    Speedy Express  (503) 555-9831
# 1   2    United Package  (503) 555-3199
# 2   3  Federal Shipping  (503) 555-9931

# %%
supplier_df.head()
# Out:
#    Id                         CompanyName                 ContactName  \
# 0   1                      Exotic Liquids            Charlotte Cooper
# 1   2          New Orleans Cajun Delights               Shelley Burke
# 2   3           Grandma Kelly's Homestead               Regina Murphy
# 3   4                       Tokyo Traders                Yoshi Nagase
# 4   5  Cooperativa de Quesos 'Las Cabras'  Antonio del Valle Saavedra
#
#            ContactTitle                    Address         City  \
# 0    Purchasing Manager             49 Gilbert St.       London
# 1   Order Administrator             P.O. Box 78934  New Orleans
# 2  Sales Representative             707 Oxford Rd.    Ann Arbor
# 3     Marketing Manager  9-8 Sekimai Musashino-shi        Tokyo
# 4  Export Administrator          Calle del Rosal 4       Oviedo
#
#             Region PostalCode Country           Phone             Fax  \
# 0    British Isles    EC1 4SD      UK  (171) 555-2222            None
# ...

# %%
supplier_df.Region.value_counts()
# Out:
# Western Europe     6
# North America      6
# Northern Europe    4
# Southern Europe    3
# Eastern Asia       2
# British Isles      2
# Scandinavia        2
# NSW                1
# South-East Asia    1
# South America      1
# Victoria           1
# Name: Region, dtype: int64

# %%
order_df.head(10)
# Out:
#       Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# 0  10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 1  10249      TOMSP           6  2012-07-05   2012-08-16  2012-07-10        1
# 2  10250      HANAR           4  2012-07-08   2012-08-05  2012-07-12        2
# 3  10251      VICTE           3  2012-07-08   2012-08-05  2012-07-15        1
# 4  10252      SUPRD           4  2012-07-09   2012-08-06  2012-07-11        2
# 5  10253      HANAR           3  2012-07-10   2012-07-24  2012-07-16        2
# 6  10254      CHOPS           5  2012-07-11   2012-08-08  2012-07-23        2
# 7  10255      RICSU           9  2012-07-12   2012-08-09  2012-07-15        3
# 8  10256      WELLI           3  2012-07-15   2012-08-12  2012-07-17        2
# 9  10257      HILAA           4  2012-07-16   2012-08-13  2012-07-22        3
#
#    Freight                   ShipName  \
# 0    32.38  Vins et alcools Chevalier
# ...

# %%
order_df.Freight.max()
# Out:
# 1007.64

# %%
order_df.ShipVia.value_counts()
# Out:
# 2    326
# 3    255
# 1    249
# Name: ShipVia, dtype: int64

# %%
product_df.head()
# Out:
#    Id                   ProductName  SupplierId  CategoryId  \
# 0   1                          Chai           1           1
# 1   2                         Chang           1           1
# 2   3                 Aniseed Syrup           1           2
# 3   4  Chef Anton's Cajun Seasoning           2           2
# 4   5        Chef Anton's Gumbo Mix           2           2
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0   10 boxes x 20 bags      18.00            39             0            10
# 1   24 - 12 oz bottles      19.00            17            40            25
# 2  12 - 550 ml bottles      10.00            13            70            25
# 3       48 - 6 oz jars      22.00            53             0             0
# 4             36 boxes      21.35             0             0             0
#
#    Discontinued
# 0             0
# 1             0
# 2             0
# 3             0
# 4             1

# %%
orderdetail_df.head()
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11       14.0        12       0.0
# 1  10248/42    10248         42        9.8        10       0.0
# 2  10248/72    10248         72       34.8         5       0.0
# 3  10249/14    10249         14       18.6         9       0.0
# 4  10249/51    10249         51       42.4        40       0.0

# %%
customercustomerdemo_df
# Out:
# Empty DataFrame
# Columns: [Id, CustomerTypeId]
# Index: []

# %%
customerdemographic_df
# Out:
# Empty DataFrame
# Columns: [Id, CustomerDesc]
# Index: []

# %%
region_df
# Out:
#    Id RegionDescription
# 0   1           Eastern
# 1   2           Western
# 2   3          Northern
# 3   4          Southern

# %%
territory_df.head()
# Out:
#       Id TerritoryDescription  RegionId
# 0  01581             Westboro         1
# 1  01730              Bedford         1
# 2  01833            Georgetow         1
# 3  02116               Boston         1
# 4  02139            Cambridge         1

# %%
employeeterritory_df.head()
# Out:
#         Id  EmployeeId TerritoryId
# 0  1/06897           1       06897
# 1  1/19713           1       19713
# 2  2/01581           2       01581
# 3  2/01730           2       01730
# 4  2/01833           2       01833

# %%
territory_df.Id.nunique()
# Out:
# 53

# %%
employeeterritory_df.TerritoryId.nunique()
# Out:
# 49

# %%
territory_df.TerritoryDescription.nunique()
# Out:
# 52

# %%
display(region_df)
display(territory_df)
display(employeeterritory_df)
display(employee_df)
# Out:
#    Id RegionDescription
# 0   1           Eastern
# 1   2           Western
# 2   3          Northern
# 3   4          Southern
#        Id TerritoryDescription  RegionId
# 0   01581             Westboro         1
# 1   01730              Bedford         1
# 2   01833            Georgetow         1
# 3   02116               Boston         1
# 4   02139            Cambridge         1
# 5   02184            Braintree         1
# 6   02903           Providence         1
# 7   03049               Hollis         3
# 8   03801           Portsmouth         3
# 9   06897               Wilton         1
# 10  07960           Morristown         1
# 11  08837               Edison         1
# 12  10019             New York         1
# 13  10038             New York         1
# 14  11747             Mellvile         1
# 15  14450             Fairport         1
# 16  19428         Philadelphia         3
# 17  19713               Neward         1
# 18  20852            Rockville         1
# ...

# %%
display(len(territory_df))
territory_df.RegionId.value_counts()
# Out:
# 53
# 1    19
# 2    15
# 3    11
# 4     8
# Name: RegionId, dtype: int64

# %%
# Dataframe all_df of employees by region
query = """SELECT e.ID, e.LastName, 
            e.FirstName, e.Title, e.Country, 
            et.TerritoryID, t.RegionID, r.RegionDescription
            FROM Employee e
            JOIN EmployeeTerritory et
            JOIN Territory t
            JOIN Region r;"""
employee_df = pd.read_sql(query, conn)
display(employee_df.head())
employee_df.describe()
# Out:
#    Id LastName FirstName                 Title Country TerritoryId  RegionId  \
# 0   1  Davolio     Nancy  Sales Representative     USA       06897         1
# 1   1  Davolio     Nancy  Sales Representative     USA       06897         1
# 2   1  Davolio     Nancy  Sales Representative     USA       06897         1
# 3   1  Davolio     Nancy  Sales Representative     USA       06897         1
# 4   1  Davolio     Nancy  Sales Representative     USA       06897         1
#
#   RegionDescription
# 0           Eastern
# 1           Western
# 2          Northern
# 3          Southern
# 4           Eastern
#                  Id      RegionId
# count  93492.000000  93492.000000
# mean       5.000000      2.150943
# std        2.582003      1.070999
# min        1.000000      1.000000
# 25%        3.000000      1.000000
# 50%        5.000000      2.000000
# 75%        7.000000      3.000000
# max        9.000000      4.000000

# %%
query = """SELECT e.ID, e.LastName, 
            e.FirstName, e.Title, e.Country, et.TerritoryID 
            FROM Employee e
            JOIN EmployeeTerritory et;"""
employee_df = pd.read_sql(query, conn)
display(employee_df.head())
# Out:
#    Id LastName FirstName                 Title Country TerritoryId
# 0   1  Davolio     Nancy  Sales Representative     USA       06897
# 1   1  Davolio     Nancy  Sales Representative     USA       19713
# 2   1  Davolio     Nancy  Sales Representative     USA       01581
# 3   1  Davolio     Nancy  Sales Representative     USA       01730
# 4   1  Davolio     Nancy  Sales Representative     USA       01833

# %%
# Gross revenue
# p.UnitPrice, od.UnitPrice, p.ProductID, od.OrderID, od.Quantity, od.Discount,

# %%
query = """SELECT c.CategoryName, p.QuantityPerUnit, od.ProductID, p.UnitPrice, od.UnitPrice, od.OrderID, od.Quantity, od.Discount
            FROM Product p
            JOIN OrderDetail od
            JOIN Category c
            ON p.CategoryID;"""
gross_rev_df = pd.read_sql(query, conn)
gross_rev_df
# Out:
#            CategoryName     QuantityPerUnit  ProductId  UnitPrice  UnitPrice  \
# 0             Beverages  10 boxes x 20 bags         11       18.0      14.00
# 1            Condiments  10 boxes x 20 bags         11       18.0      14.00
# 2           Confections  10 boxes x 20 bags         11       18.0      14.00
# 3        Dairy Products  10 boxes x 20 bags         11       18.0      14.00
# 4        Grains/Cereals  10 boxes x 20 bags         11       18.0      14.00
# 5          Meat/Poultry  10 boxes x 20 bags         11       18.0      14.00
# 6               Produce  10 boxes x 20 bags         11       18.0      14.00
# 7               Seafood  10 boxes x 20 bags         11       18.0      14.00
# 8             Beverages  10 boxes x 20 bags         42       18.0       9.80
# 9            Condiments  10 boxes x 20 bags         42       18.0       9.80
# 10          Confections  10 boxes x 20 bags         42       18.0       9.80
# ...

# %%
display(product_df.head(15))
display(orderdetail_df.head(15))
display(category_df)
# Out:
#     Id                      ProductName  SupplierId  CategoryId  \
# 0    1                             Chai           1           1
# 1    2                            Chang           1           1
# 2    3                    Aniseed Syrup           1           2
# 3    4     Chef Anton's Cajun Seasoning           2           2
# 4    5           Chef Anton's Gumbo Mix           2           2
# 5    6     Grandma's Boysenberry Spread           3           2
# 6    7  Uncle Bob's Organic Dried Pears           3           7
# 7    8       Northwoods Cranberry Sauce           3           2
# 8    9                  Mishi Kobe Niku           4           6
# 9   10                            Ikura           4           8
# 10  11                   Queso Cabrales           5           4
# 11  12        Queso Manchego La Pastora           5           4
# 12  13                            Konbu           6           8
# 13  14                             Tofu           6           7
# ...

# %%
query = """SELECT p.ID, p.ProductName, c.CategoryName, 
            p.QuantityPerUnit, p.UnitPrice, 
            od.UnitPrice, od.Quantity, 
            od.Discount
            FROM Product p
            JOIN OrderDetail od
            ON p.ID = od.ProductID
            JOIN Category c
            ON p.CategoryID = c.ID;"""
join = pd.read_sql(query, conn)
join.head(20)
# Out:
#     Id                       ProductName    CategoryName    QuantityPerUnit  \
# 0   11                    Queso Cabrales  Dairy Products          1 kg pkg.
# 1   42     Singaporean Hokkien Fried Mee  Grains/Cereals    32 - 1 kg pkgs.
# 2   72            Mozzarella di Giovanni  Dairy Products   24 - 200 g pkgs.
# 3   14                              Tofu         Produce   40 - 100 g pkgs.
# 4   51             Manjimup Dried Apples         Produce   50 - 300 g pkgs.
# 5   41   Jack's New England Clam Chowder         Seafood    12 - 12 oz cans
# 6   51             Manjimup Dried Apples         Produce   50 - 300 g pkgs.
# 7   65  Louisiana Fiery Hot Pepper Sauce      Condiments  32 - 8 oz bottles
# 8   22               Gustaf's Knäckebröd  Grains/Cereals   24 - 500 g pkgs.
# 9   57                    Ravioli Angelo  Grains/Cereals   24 - 250 g pkgs.
# 10  65  Louisiana Fiery Hot Pepper Sauce      Condiments  32 - 8 oz bottles
# ...

# %%
join['OrderDate'] = order_df['OrderDate']
check = join[join['Id'] == 11]
check
# Out:
#       Id     ProductName    CategoryName QuantityPerUnit  UnitPrice  \
# 0     11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 129   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 210   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 280   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 313   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 425   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 491   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 513   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 516   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 582   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 631   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 639   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# 742   11  Queso Cabrales  Dairy Products       1 kg pkg.       21.0
# ...

# %% [markdown]
# od.UnitPrice is the price that the good was sold for at the time. p.UnitPrice reflects the current price of the good. Prove that od.UP is always less than or equal to p.UP. Investigate if there is a statistically

# %% [markdown]
# gross_rev = od.UnitPrice * od.Quantity * (1-od.Discount) for each product ordered
#
# sum up for each employee
#
# compare gross revenue by employee
# compare total orders by employee

# %% [markdown]
# gross revenue by employee

# %%
display(order_df.OrderDate.max(), order_df.OrderDate.min())
# Out:
# '2014-05-06'
# '2012-07-04'

# %%
order_df.isna().sum()
# Out:
# Id                 0
# CustomerId         0
# EmployeeId         0
# OrderDate          0
# RequiredDate       0
# ShippedDate       21
# ShipVia            0
# Freight            0
# ShipName           0
# ShipAddress        0
# ShipCity           0
# ShipRegion         0
# ShipPostalCode    19
# ShipCountry        0
# dtype: int64

# %% [markdown]
# # Testing Employee Question

# %%
query = """SELECT od.OrderId, od.UnitPrice, od.Quantity, od.Discount, o.EmployeeID
            FROM [Order] o
            JOIN OrderDetail od
            ON o.ID == od.OrderID
            WHERE o.EmployeeID == 1"""

# %%
test = pd.read_sql(query, conn)
test.head()
# Out:
#    OrderId  UnitPrice  Quantity  Discount  EmployeeId
# 0    10258       15.2        50       0.2           1
# 1    10258       17.0        65       0.2           1
# 2    10258       25.6         6       0.2           1
# 3    10270       15.2        30       0.0           1
# 4    10270       36.8        25       0.0           1

# %%
quantity = sum(test.Quantity)
quantity
# Out:
# 7812

# %%
# Calculate Average Gross Revenue per Order for Employee 1
gross_rev = sum(test.UnitPrice * test.Quantity * (1-test.Discount))
ave_gross_rev = gross_rev/quantity
ave_gross_rev
# Out:
# 24.591347222222232

# %%
order_df.OrderDate.unique()
# Out:
# array(['2012-07-04', '2012-07-05', '2012-07-08', '2012-07-09',
#        '2012-07-10', '2012-07-11', '2012-07-12', '2012-07-15',
#        '2012-07-16', '2012-07-17', '2012-07-18', '2012-07-19',
#        '2012-07-22', '2012-07-23', '2012-07-24', '2012-07-25',
#        '2012-07-26', '2012-07-29', '2012-07-30', '2012-07-31',
#        '2012-08-01', '2012-08-02', '2012-08-05', '2012-08-06',
#        '2012-08-07', '2012-08-08', '2012-08-09', '2012-08-12',
#        '2012-08-13', '2012-08-14', '2012-08-15', '2012-08-16',
#        '2012-08-19', '2012-08-20', '2012-08-21', '2012-08-22',
#        '2012-08-23', '2012-08-26', '2012-08-27', '2012-08-28',
#        '2012-08-29', '2012-08-30', '2012-09-02', '2012-09-03',
#        '2012-09-04', '2012-09-05', '2012-09-06', '2012-09-09',
#        '2012-09-10', '2012-09-11', '2012-09-12', '2012-09-13',
#        '2012-09-16', '2012-09-17', '2012-09-18', '2012-09-19',
#        '2012-09-20', '2012-09-23', '2012-09-24', '2012-09-25',
# ...
